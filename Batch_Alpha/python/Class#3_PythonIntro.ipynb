# %% [markdown]
# <font color=red> Understanding of Python Programming language </font>
# =========================================
#
# **What is Python?** <br>
# Python is a very popular general-purpose interpreted, interactive, object-oriented, and high-level programming language. Python is dynamically-typed and garbage-collected programming language. It was created by Guido van Rossum during 1985- 1990. Like Perl, Python source code is also available under the GNU General Public License (GPL).
#
# Advantages
# ==========
# **Python is Interpreted** − Python is processed at runtime by the interpreter. You do not need to compile your program before executing it. This is similar to PERL and PHP.
#
# **Python is Interactive** − You can actually sit at a Python prompt and interact with the interpreter directly to write your programs.
#
# **Python is Object-Oriented** − Python supports Object-Oriented style or technique of programming that encapsulates code within objects.
#
# **Python is a Beginner's Language** − Python is a great language for the beginner-level programmers and supports the development of a wide range of applications from simple text processing to WWW browsers to games.
#
# Python Vs C++
# ============
# - Compiled vs Interpreted
# - Cross platform
# - Portability
# - Speed of Development
# - Easy to Learn
# - Static vs Dynamic Typing
# - OOP Concepts
# - Garbage Collection
# - Application Areas

# %% [markdown]
# ![python_interpreter.jpg](attachment:python_interpreter.jpg)

# %% [markdown]
# INDENTATION
# ===========
#
# the space we give before writing a line of code

# %%
def sum(num1, num2):
    add=num1+num2 #maintaining the space before code
    return add

print(sum(5,6))
# Out:
# 11

# %%
num=-1
if(num>0):
    print("I am pstv number")
    
    if(num==5):
        print("Yes I am 5")
    else:
        print("I am not 5")
        
else:
    print("Not a pstv no.")
# Out:
# Not a pstv no.

# %% [markdown]
# COMMENT
# =========
# this is a human readable lines what computer ignores whlie compiling

# %%
#this is a single comment -> one line comment

#====multiline comments====

'''
I 
am 
a 
multiline
comment

'''
# Out:
# '\nI \nam \na \nmultiline\ncomment\n\n'

# %% [markdown]
# Variables
# ========

# %%
a=5
b="string"
c=3.0

# %% [markdown]
# CASTING
# =======

# %%
a=str(a)
z="5"
int(z)
print(z)
# Out:
# 5

# %% [markdown]
# CASE SENSITIVE
# ==============

# %%
a="Low"
b="low"

if(a==b):
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# CAMEL CASE, SNAKE CASE, PASCAL CASE
# =====================================

# %%
myVariable = 5 #-> this is an example of camel case
my_variable = 5 #-> snake case
MyVarible =5 #->pascal case

# %% [markdown]
# Assign Multiple Values to variables at one time
# ======================================

# %%
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %% [markdown]
# COLLECTION
# ===========
# - list
# - tuple
# - dictionary

# %%
Dataspace_Classroom = ["Shirin", "Tapas", "Santanu"]

x, y, z = Dataspace_Classroom

# %%
print(x)
# Out:
# Shirin

# %%
print(y)
# Out:
# Tapas

# %%
print(z)
# Out:
# Santanu

# %% [markdown]
# GLOBAL VARIBLE
# ==============

# %%
num=5

def sub1(num1,num2):
    normal_variable=2
    var1 =num1  + num
    var2 = num2 - num
    
    sub=var1 - var2
    
    return sub

def sub(num1,num2):
    var1 =num1 + num
    var2 = num2 - num
    
    sub=var1 - var2
    
    return sub


print(sub1(5,1))
# Out:
# 14

# %%
OPERATORS
=========
