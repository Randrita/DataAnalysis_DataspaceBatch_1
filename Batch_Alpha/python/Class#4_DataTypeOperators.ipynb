# %% [markdown]
# <font color=red>Datatypes, Operators, Loop, Functions </font>
# ===============================

# %% [markdown]
# **Built-In Data Types** <br>
# In programming, data type is an important concept. Variables can store data of different types, and different types can do different things.

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# NUMBERS
# =========
# - int
# - float
# - complex

# %%
a=5
b=5.2
c=4+5j

print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
#Create a list
dataspace = ["Randrita", "Subhasis", "Ajaj"]
dataspace_numbers = [23,23,23]


dataspace_list = ["Randrita",23 , "Subhasis", 23 , "Ajaj", 23]
for i in range(len(dataspace_list)): 
    if(dataspace_list[i]=='Randrita'):
        print("wohooooooooooo!!")
        
dataspace_list.append("Santanu")
print(dataspace_list)

#print(dataspace_list)
    
    
dataspace_dict = {"Randrita":23 , "Subhasis": 23 , "Ajaj": 23}
dataspace_tuple = ("Randrita",23 , "Subhasis", 23 , "Ajaj", 23)
dataspace_set = {"Randrita",23 , "Subhasis", 23 , "Ajaj", 23}
dataspace_frozenset = ({"Randrita",23 , "Subhasis", 23 , "Ajaj", 23})

#type(dataspace_set)

#print(range(10))
# Out:
# wohooooooooooo!!
# ['Randrita', 23, 'Subhasis', 23, 'Ajaj', 23, 'Santanu']

# %% [markdown]
# TYPE CONVERSION
# ===============

# %%
#conversion of float to int
print(int(b))

#conversion of int to float
print(float(a))

#conversion of int to complex
print(complex(a))

#Remember : we can't convert complex no. to any real no.
# Out:
# 5
# 5.0
# (5+0j)

# %% [markdown]
# **PROJECT 1 : Generate an app which will produce a random number**

# %%
import random

print (random.randrange(1,100))
# Out:
# 84

# %% [markdown]
# OPERATORS
# ===========
#
# - Assignment operator
# - Arithmatic Operator
# - logical operator
# - bitwise operator
# - comparison operator
# - Identity
# - Membership

# %%
#Arthmatich Operator
#+ , -, *, //->floor division, /-> float division , % , **

print(5%3) #-> #returns reminder
print(5/3)#-> #1.666 ->float value
print(5//3) #-> #whole number
# Out:
# 2
# 1.6666666666666667
# 1

# %%
#Assignment Operator
#==, =, *=, /=, %=

a=10
b=2
a%=6
print(a)
print(a==b)
# Out:
# 4
# False

# %%
#Comparison Operator
#>=, >, < ,<=,

#logical operator
#and, or, not
a=10
b=4
c=5
if(a>b and c<b):
    print('true')
else:
    print('false')
    
#logical operator
a=10
b=4
c=5
if(a>b or c<b):
    print('true')
else:
    print('false')    
#print(5 or 3)

a=[1,2,3]
b=5
for i in range(len(a)):
    if b not in a:
        print('false')
# Out:
# false
# true
# false
# false
# false

# %% [markdown]
# IDENTITY OPERATOR
# ==================

# %%
a=[1,2,3]
b=[1,2,3]
b=a
print(a is b)
# Out:
# True
